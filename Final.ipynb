# %% [markdown]
# # <span style="color: violet;">Maternal Mental Health in Pregnancy during COVID-19
#  </span>

# %% [markdown]
# ### <span style="color: violet;">Sophia Dalal, April 26 2025 <span>

# %% [markdown]
# ### <span style="color: violet;"> Introduction:  <span>

# %% [markdown]
# ##### <span style="color: lightpink;">This data set is centered around prenatal individuals birth outcomes in the pregnancy during the COVID. This Dataset aimed to understand the impact of COVID-19-related stresses on pregnant individuals and their infants and collected survey-based data across Canada as part of the Pregnancy during the COVID-19 Pandemic project.</span> </span>

# %% [markdown]
# ##### <span style="color: lightpink;">The COVID-19 pandemic posed significant challenges to maternal health worldwide, amplifying stress, anxiety, and depression among pregnant and postpartum individuals. These mental health challenges were not experienced equally—language barriers often exacerbated health disparities. Non-English speaking individuals may have faced reduced access to information, limited communication with healthcare providers, and increased social isolation, all of which can intensify psychological distress.<span>
#
# ##### <span style="color: lightpink;">Language can serve as a proxy for broader cultural and structural inequalities, influencing not only maternal mental health but also birth outcomes such as gestational age, birth weight, and NICU admission rates. Despite its importance, language-based disparities in perinatal health have been underexplored, particularly in the context of large-scale public health crises like COVID-19. <span>
#
# ##### <span style="color: lightpink;">By examining differences in mental health scores and birth outcomes between English and non-English speaking participants, this study aims to shed light on the intersection between linguistic marginalization and maternal-infant wellbeing, with implications for equitable care and policy design.<span>

# %% [markdown]
# ### <span style="color: violet;"> Here is a  description of all the variables used in the data set:
#  </span>

# %% [markdown]
# ##### <span style="color: lightpink;">  Maternal_Age = Maternal age (years) at intake <span>
#
#
# ##### <span style="color: lightpink;"> Household_Income = What is the total household income, before taxes and deductions, of all the household members from all sources in 2019<span>
#
#
# ##### <span style="color: lightpink;"> Maternal_Education = Maternal education<span>
#
#
# ##### <span style="color: lightpink;">
#
# 1- Less than high school
#
# 2- diploma
#
# 3- High school diploma
#
# 4- College/trade school
#
# 5- Undergraduate degree
#
# 6- Master's degree
#
# 7- Doctoral Degree<span>
#
# ##### <span style="color: lightpink;"> EPDS = Edinburgh Postnatal Depression Scale (you can find the survey on the internet)<span>
#
# ##### <span style="color: lightpink;"> PROMIS_Anxiety = Score from 7 to 35 with higher scores indicating greater severity of anxiety. <span>
#
# ##### <span style="color: lightpink;"> GAbirth = Gestational age at birth (in weeks) <span>
#
# ##### <span style="color: lightpink;"> Delivery_Date = Delivery Date (Dates converted to month/year of birth)<span>
#
# ##### <span style="color: lightpink;"> Birth_Length = Birth length in cm<span>
#
# ##### <span style="color: lightpink;"> Birth_Weight = Birth weight in grams<span>
#
# ##### <span style="color: lightpink;"> Delivery_Mode = Vaginally or Caesarean-section (c-section)<span>
#
# ##### <span style="color: lightpink;"> NICU_stay = Was your infant admitted to the NICU?<span>
#
# ##### <span style="color: lightpink;"> Language = Survey language<span>
#
# ##### <span style="color: lightpink;"> Threaten_Life = How much do (did) you think your life is (was) in danger during the COVID-19 pandemic? (0-100)<span>
#
# ##### <span style="color: lightpink;"> Threaten_Baby_Danger = How much do (did) you think your unborn baby's life is (was) in danger at any time during the COVID-19 pandemic? (0-100)<span>
#
# ##### <span style="color: lightpink;"> Threaten_Baby_Harm = How much are you worried that exposure to the COVID-19 virus will harm your unborn baby? (0-100) <span>

# %% [markdown]
# ### <span style="color: violet;"> Research Question: </span>
# ### <span style="color: violet;"> Are there differences in outcomes and or mental health scores between English and non-English speaking participants? </span>
# ### <span style="color: violet;"> Goal:</span>
# ### <span style="color: violet;"> To see if lanaguage is a predictor for any mental health outcomes or baby outcomes.
#  </span>

# %% [markdown]
# ##### <span style="color: lightpink;"> Independent Variable= Language <span>
#
# ##### <span style="color: lightpink;"> Dependent Variables = EPDS score, PROMIS anxiety scales, Birth Weight, Gestational Age <span>
#
# ##### <span style="color: lightpink;"> Implication: Language as a proxy for health inequities.<span>

# %% [markdown]
# ### <span style="color: violet;"> Methods:
#  </span>

# %% [markdown]
# ##### <span style="color: lightpink;"> This data came from kaggle. It was posted by usar: yeganehbavafa. We took the csv file and made many visual and numerical figures and comparing ones language to their mental health and birth outcomes. T-tests and regression analysis were used to see if language was a signficant predictor of mental health and birth outcomes. Below this paragraph are all the steps we took to compelte this data visualization and analysis. <span>

# %% [markdown]
# #### Import all packages

# %%
import numpy as np 
import pandas as pd 
from scipy import stats 
import seaborn as sns
from pandas import DataFrame
import statsmodels.api as sm
import plotly.graph_objects as go
import plotly.express as px 
import plotly.figure_factory as ff
import plotly.io as pio
pio.templates.default = "plotly_white"
import statsmodels.api as sm 
from patsy import dmatrices

# %% [markdown]
# #### Import Data Set

# %%
df = pd.read_csv('Original Pregnancy During the COVID-19 Pandemic!!.csv')

# %% [markdown]
# #### Columns in the Data Set

# %%
# Show the column headers in the data set 
df.columns
# Out:
# Index(['OSF_ID', 'Maternal_Age', 'Household_Income', 'Maternal_Education',
#        'Edinburgh_Postnatal_Depression_Scale', 'PROMIS_Anxiety',
#        'Gestational_Age_At_Birth',
#        'Delivery_Date(converted to month and year)', 'Birth_Length',
#        'Birth_Weight', 'Delivery_Mode', 'NICU_Stay', 'Language',
#        'Threaten_Life', 'Threaten_Baby_Danger', 'Threaten_Baby_Harm'],
#       dtype='object')

# %%
# Show information about df 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10772 entries, 0 to 10771
# Data columns (total 16 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   OSF_ID                                      10772 non-null  int64
#  1   Maternal_Age                                10661 non-null  float64
#  2   Household_Income                            10521 non-null  object
#  3   Maternal_Education                          10595 non-null  object
#  4   Edinburgh_Postnatal_Depression_Scale        9598 non-null   float64
#  5   PROMIS_Anxiety                              9566 non-null   float64
#  6   Gestational_Age_At_Birth                    6734 non-null   float64
#  7   Delivery_Date(converted to month and year)  6733 non-null   object
#  8   Birth_Length                                5480 non-null   float64
# ...

# %% [markdown]
# #### <span style="color: violet;">Categorical Data:</span>

# %% [markdown]
# #### <span style="color: lightpink;">Below are ways to show the categorical variable of Language</span>

# %%
# Show the unique values of the Language column
df['Language'].unique()
# Out:
# array(['English', 'French'], dtype=object)

# %%
 # Calculate the frequency of each category in the Language column
language_counts = df['Language'].value_counts()
# Print the frequency counts
print(language_counts)
# Out:
# Language
# English    8155
# French     2617
# Name: count, dtype: int64

# %%
# Calculate the proportion of each category in the Language column
language_proportions = df['Language'].value_counts(normalize=True)
# Print the proportion counts
print(language_proportions)
# Out:
# Language
# English    0.757055
# French     0.242945
# Name: proportion, dtype: float64

# %%
# Calculate the percetage of each category in the percentage in the Language column
language_percentages = df['Language'].value_counts(normalize=True) * 100
# Print the percentage counts
print(language_percentages)
# Out:
# Language
# English    75.705533
# French     24.294467
# Name: proportion, dtype: float64

# %% [markdown]
# ## <span style="color: violet;"> Results:
#  </span>

# %% [markdown]
# #### <span style="color: violet;">Comparative Numerical Analysis:</span>

# %% [markdown]
# #### <span style="color: Lightpink;">Below are ways to compare numerical to catgeorical. Examples such as EPDS score, PROMIS Anxiety score, gestational age, and birth weight versus Language. </span>

# %%
# Calculate the mean of the EPDS score Column for each of the Language categories (Categorical and then Numerical )
df.groupby('Language')['Edinburgh_Postnatal_Depression_Scale'].mean()
# Out:
# Language
# English    10.414185
# French      9.461538
# Name: Edinburgh_Postnatal_Depression_Scale, dtype: float64

# %%
# Calculate the mean of the PROMIS Anxiety Column for each of the Language categories (Categorical and then Numerical)
df.groupby('Language')['PROMIS_Anxiety'].mean()
# Out:
# Language
# English    18.958005
# French     17.743659
# Name: PROMIS_Anxiety, dtype: float64

# %%
# Calculate the mean gestational age for each of the language categories (Catgeorical and then Numerical)
df.groupby('Language')['Gestational_Age_At_Birth'].mean()
# Out:
# Language
# English    39.35050
# French     39.30887
# Name: Gestational_Age_At_Birth, dtype: float64

# %%
# Calculate the mean birth weight for each of the language categories (Categorical and then Numerical)
df.groupby('Language')['Birth_Weight'].mean()
# Out:
# Language
# English    3424.279439
# French     3360.911283
# Name: Birth_Weight, dtype: float64

# %% [markdown]
# #### <span style="color: violet;"> Summary Statistics:</span>

# %% [markdown]
# #### <span style="color: Lightpink;">Below are ways to express the numerical variables of EPDS score, PROMIS Anxiety, Gestational age and Birth Weight. </span>

# %%
# Describe the summary statistics of the Edinburgh Postnatal Depression Scale (EPDS) scores
df['Edinburgh_Postnatal_Depression_Scale'].describe()
# Out:
# count    9598.000000
# mean       10.194832
# std         5.505230
# min         0.000000
# 25%         6.000000
# 50%        10.000000
# 75%        14.000000
# max        30.000000
# Name: Edinburgh_Postnatal_Depression_Scale, dtype: float64

# %%
# Describe the summary statistics of the PROMIS Anxiety scores
df['PROMIS_Anxiety'].describe()
# Out:
# count    9566.000000
# mean       18.677713
# std         6.084313
# min         7.000000
# 25%        14.000000
# 50%        19.000000
# 75%        23.000000
# max        35.000000
# Name: PROMIS_Anxiety, dtype: float64

# %%
# Describe the summary statistics of the Gestational Age at Birth
df['Gestational_Age_At_Birth'].describe()
# Out:
# count    6734.000000
# mean       39.342241
# std         1.612483
# min        24.860000
# 25%        38.570000
# 50%        39.570000
# 75%        40.430000
# max        42.860000
# Name: Gestational_Age_At_Birth, dtype: float64

# %%
# Describe the summary statistics of the Birth Weight
df['Birth_Weight'].describe()
# Out:
# count    6078.000000
# mean     3412.175058
# std       538.695046
# min       303.000000
# 25%      3102.250000
# 50%      3431.000000
# 75%      3742.000000
# max      5968.000000
# Name: Birth_Weight, dtype: float64

# %% [markdown]
# #### <span style="color: Lightpink;">Below are ways to express the numerical variables of EPDS score, PROMIS Anxiety, Gestational age and Birth Weight in relationship with language (english versus french) </span>

# %%
# summary statistics for the Edinburge Postpartum column for each category of the 'Language' column
df.groupby('Language')['Edinburgh_Postnatal_Depression_Scale'].describe()
# Out:
#            count       mean       std  min  25%   50%   75%   max
# Language
# English   7388.0  10.414185  5.399369  0.0  6.0  10.0  14.0  30.0
# French    2210.0   9.461538  5.786422  0.0  5.0   9.0  13.0  29.0

# %%
# summary statistics for the PROMIS Anxiety column for each category of the 'Language' column
df.groupby('Language')['PROMIS_Anxiety'].describe()
# Out:
#            count       mean       std  min   25%   50%   75%   max
# Language
# English   7358.0  18.958005  6.032827  7.0  14.0  19.0  23.0  35.0
# French    2208.0  17.743659  6.162830  7.0  13.0  18.0  23.0  35.0

# %%
# summary statistics for the age column for each category of the 'Delivery_Mode' column
df.groupby('Language')['Gestational_Age_At_Birth'].describe()
# Out:
#            count      mean       std    min    25%    50%    75%    max
# Language
# English   5398.0  39.35050  1.613136  24.86  38.57  39.43  40.43  42.86
# French    1336.0  39.30887  1.610013  27.29  38.57  39.57  40.29  42.29

# %%
# summary statistics for the age column for each category of the 'Delivery_Mode' column
df.groupby('Language')['Birth_Weight'].describe()
# Out:
#            count         mean         std    min     25%     50%     75%  \
# Language
# English   4917.0  3424.279439  535.336730  303.0  3119.0  3431.0  3742.0
# French    1161.0  3360.911283  549.979257  314.0  3080.0  3374.0  3689.0
#
#              max
# Language
# English   5968.0
# French    5675.0

# %% [markdown]
# ### <span style="color: violet;"> Data Visualization (Frequency Diagrams):</span>

# %%
# %config InlineBackend.figure_format = 'retina'
#Add a hue that shows which language the participant speaks
sns.displot(
    df,
    x='Edinburgh_Postnatal_Depression_Scale',
    hue='Language',
    kde=True
).set(
    title='EPDS distribution by Language',
    xlabel='EPDS Score',
    ylabel='Frequency'
);

# %%
#Stacked histogram of the EPDS scores by Language
fig = px.histogram(
    df,
    x='Edinburgh_Postnatal_Depression_Scale',
    color='Language',
    barmode='stack',
    title='EPDS Scores by Language'
)
fig.update_layout(
    xaxis_title='EPDS Score',
    yaxis_title='Count'
)
fig.show()

# %%
sns.displot(
    df,
    x='PROMIS_Anxiety',
    hue='Language',
    kde=True
).set(
    title='Anxiety Score  by Language',
    xlabel='Anxiety Score',
    ylabel='Frequency'
);

# %%
#Stacked histogram of the Anxiety scores by Language
fig = px.histogram(
    df,
    x='PROMIS_Anxiety',
    color='Language',
    barmode='stack',
    title='Anxiety Scores by Language'
)
fig.update_layout(
    xaxis_title='Anxiety Score',
    yaxis_title='Count'
)
fig.show()

# %%
sns.displot(
    df,
    x='Gestational_Age_At_Birth',
    hue='Language',
    kde=True
).set(
    title='Gestational Age at Birth by Language',
    xlabel='Gestational Age at Birth',
    ylabel='Frequency'
);

# %%
#Stacked histogram of the Gestational Age at Birth by Language
fig = px.histogram(
    df,
    x='Gestational_Age_At_Birth',
    color='Language',
    barmode='stack',
    title='Gestational Age at Birth by Language'
)
fig.update_layout(
    xaxis_title='Gestational Age at Birth',
    yaxis_title='Count'
)
fig.show()

# %%
sns.displot(
    df,
    x='Birth_Weight',
    hue='Language',
    kde=True
).set(
    title='Birth Weight by Language',
    xlabel='Birth Weight',
    ylabel='Frequency'
);

# %%
#Stacked histogram of the Birth Weight by Language
fig = px.histogram(
    df,
    x='Birth_Weight',
    color='Language',
    barmode='stack',
    title='Birth Weight by Language'
)
fig.update_layout(
    xaxis_title='Birth Weight',
    yaxis_title='Count'
)
fig.show()

# %%
sns.displot(
    df,
    x='Edinburgh_Postnatal_Depression_Scale',
    bins=range(0, 30, 1),
    hue='Language',
    col='Language',
    stat='density'
).set(
    title='EPDS distribution by Language',
    xlabel='EPDS Score',
    ylabel='Frequency'
)

# %%
#Do the same as above but for the Anxiety scores
sns.displot(
    df,
    x='PROMIS_Anxiety',
    bins=range(0, 30, 1),
    hue='Language',
    col='Language',
    stat='density'
).set(
    title='Anxiety distribution by Language',
    xlabel='Anxiety Score',
    ylabel='Frequency'
)

# %%
#Do the same as above but for the Gestational Age at Birth
sns.displot(
    df,
    x='Gestational_Age_At_Birth',
    bins=range(0, 43, 1),
    hue='Language',
    col='Language',
    stat='density'
).set(
    title='Gestational Age at Birth distribution by Language',
    xlabel='Gestational Age at Birth',
    ylabel='Frequency'
)

# %%
#Do the same as above but for the Birth Weight
sns.displot(
    df,
    x='Birth_Weight',
    bins=range(1000, 6000, 100),
    hue='Language',
    col='Language',
    stat='density'
).set(
    title='Birth Weight distribution by Language',
    xlabel='Birth Weight',
    ylabel='Frequency'
)

# %% [markdown]
# ### <span style="color: violet;"> Data Visualization (Boxplots):</span>

# %%
#Create a boxplot of the EPDS scores by Language
fig = px.box(
    df,
    x='Language',
    y='Edinburgh_Postnatal_Depression_Scale',
    title='EPDS Scores by Language'
)
fig.update_layout(
    xaxis_title='Language',
    yaxis_title='EPDS Score'
)
fig.show()

# %%
#Create a boxplot of the Anxiety scores by Language
fig = px.box(
    df,
    x='Language',
    y='PROMIS_Anxiety',
    title='Anxiety Scores by Language'
)
fig.update_layout(
    xaxis_title='Language',
    yaxis_title='Anxiety Score'
)
fig.show()

# %%
#Create a boxplot of the Gestational Age at Birth by Language
fig = px.box(
    df,
    x='Language',
    y='Gestational_Age_At_Birth',
    title='Gestational Age at Birth by Language'
)
fig.update_layout(
    xaxis_title='Language',
    yaxis_title='Gestational Age at Birth'
)
fig.show()

# %%
#Create a boxplot of the Birth Weight by Language
fig = px.box(
    df,
    x='Language',
    y='Birth_Weight',
    title='Birth Weight by Language'
)
fig.update_layout(
    xaxis_title='Language',
    yaxis_title='Birth Weight'
)
fig.show()

# %% [markdown]
# ### <span style="color: violet;"> Data Visualization (Scatter Plots):</span>

# %%
#Create a scatter plot of the EPDS scores by Language
fig = px.scatter(
    df,
    x='Language',
    y='Edinburgh_Postnatal_Depression_Scale',
    title='EPDS Scores by Language'
)
fig.update_layout(
    xaxis_title='Language',
    yaxis_title='EPDS Score'
)
fig.show()

# %%
#Create a scatter plot of the Anxiety scores by Language
fig = px.scatter(
    df,
    x='Language',
    y='PROMIS_Anxiety',
    title='Anxiety Scores by Language'
)
fig.update_layout(
    xaxis_title='Language',
    yaxis_title='Anxiety Score'
)
fig.show()

# %%
#Create a scatter plot of the Gestational Age at Birth by Language
fig = px.scatter(
    df,
    x='Language',
    y='Gestational_Age_At_Birth',
    title='Gestational Age at Birth by Language'
)
fig.update_layout(
    xaxis_title='Language',
    yaxis_title='Gestational Age at Birth'
)
fig.show()

# %%
#Create a scatter plot of the Birth Weight by Language
fig = px.scatter(
    df,
    x='Language',
    y='Birth_Weight',
    title='Birth Weight by Language'
)
fig.update_layout(
    xaxis_title='Language',
    yaxis_title='Birth Weight'
)
fig.show()

# %% [markdown]
# ### <span style="color: lightpink;"> Comparing the relationship between Language and EPDS, Anxiety Score, Gestational Age, and Birth Weight </span>

# %% [markdown]
# #### <span style="color: violet;">Statistical Analysis (Independent T Test):</span>

# %%
# Filter the data for English and French speakers
english_speakers = df[df['Language'] == 'English']['Edinburgh_Postnatal_Depression_Scale']
french_speakers = df[df['Language'] == 'French']['Edinburgh_Postnatal_Depression_Scale']

# Perform an independent t-test
t_stat, p_value = stats.ttest_ind(english_speakers, french_speakers, nan_policy='omit')

# Print the t-statistic and p-value
print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: 7.155806708397219, P-value: 8.927672159043694e-13

# %%
#Do the same as above but for the Anxiety scores
english_speakers = df[df['Language'] == 'English']['PROMIS_Anxiety']
french_speakers = df[df['Language'] == 'French']['PROMIS_Anxiety']
# Perform an independent t-test
t_stat, p_value = stats.ttest_ind(english_speakers, french_speakers, nan_policy='omit')
# Print the t-statistic and p-value
print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: 8.253983975665555, P-value: 1.7347309387819502e-16

# %%
#Do the same as above but for the Gestational Age at Birth
english_speakers = df[df['Language'] == 'English']['Gestational_Age_At_Birth']
french_speakers = df[df['Language'] == 'French']['Gestational_Age_At_Birth']
# Perform an independent t-test
t_stat, p_value = stats.ttest_ind(english_speakers, french_speakers, nan_policy='omit')
# Print the t-statistic and p-value 
print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: 0.8448694475629546, P-value: 0.3982137587333381

# %%
#Do the same as above but for the Birth Weight
english_speakers = df[df['Language'] == 'English']['Birth_Weight']
french_speakers = df[df['Language'] == 'French']['Birth_Weight']
# Perform an independent t-test
t_stat, p_value = stats.ttest_ind(english_speakers, french_speakers, nan_policy='omit')
# Print the t-statistic and p-value
print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: 3.608636284213736, P-value: 0.00031028717491140146

# %% [markdown]
# #### <span style="color: violet;">Statistical Analysis (Linear Regression):</span>

# %% [markdown]
# #### <span style="color: lightpink;">Unadjusted Linear Regressions:</span>

# %%
#Do a linear regression with the EPDS score as the dependent variable and the Language as the independent variable
#Create the design matrix
y, X = dmatrices('Edinburgh_Postnatal_Depression_Scale ~ Language', data=df, return_type='dataframe')
#Fit the model
model = sm.OLS(y, X).fit()
#Print the summary
print(model.summary())
# Out:
#                                      OLS Regression Results
# ...
# Dep. Variable:     Edinburgh_Postnatal_Depression_Scale   R-squared:                       0.005
# Model:                                              OLS   Adj. R-squared:                  0.005
# Method:                                   Least Squares   F-statistic:                     51.21
# Date:                                  Tue, 29 Apr 2025   Prob (F-statistic):           8.93e-13
# Time:                                          20:46:58   Log-Likelihood:                -29964.
# No. Observations:                                  9598   AIC:                         5.993e+04
# Df Residuals:                                      9596   BIC:                         5.995e+04
# Df Model:                                             1
# Covariance Type:                              nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
#Do a linear regression with the Anxiety score as the dependent variable and the Language as the independent variable
#Create the design matrix
y, X = dmatrices('PROMIS_Anxiety ~ Language', data=df, return_type='dataframe')
#Fit the model
model = sm.OLS(y, X).fit()
#Print the summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         PROMIS_Anxiety   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     68.13
# Date:                Tue, 29 Apr 2025   Prob (F-statistic):           1.73e-16
# Time:                        20:49:05   Log-Likelihood:                -30813.
# No. Observations:                9566   AIC:                         6.163e+04
# Df Residuals:                    9564   BIC:                         6.164e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             18.9580      0.071    268.213      0.000      18.819      19.097
# ...

# %%
#Do a linear regression with the Gestational Age at Birth as the dependent variable and the Language as the independent variable
#Create the design matrix
y, X = dmatrices('Gestational_Age_At_Birth ~ Language', data=df, return_type='dataframe')
#Fit the model
model = sm.OLS(y, X).fit()
#Print the summary
print(model.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     Gestational_Age_At_Birth   R-squared:                       0.000
# Model:                                  OLS   Adj. R-squared:                 -0.000
# Method:                       Least Squares   F-statistic:                    0.7138
# Date:                      Tue, 29 Apr 2025   Prob (F-statistic):              0.398
# Time:                              20:49:17   Log-Likelihood:                -12772.
# No. Observations:                      6734   AIC:                         2.555e+04
# Df Residuals:                          6732   BIC:                         2.556e+04
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
#Do a linear regression with the Birth Weight as the dependent variable and the Language as the independent variable
#Create the design matrix
y, X = dmatrices('Birth_Weight ~ Language', data=df, return_type='dataframe')
#Fit the model
model = sm.OLS(y, X).fit()
#Print the summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Birth_Weight   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     13.02
# Date:                Tue, 29 Apr 2025   Prob (F-statistic):           0.000310
# Time:                        20:49:28   Log-Likelihood:                -46843.
# No. Observations:                6078   AIC:                         9.369e+04
# Df Residuals:                    6076   BIC:                         9.370e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           3424.2794      7.675    446.175      0.000    3409.234    3439.325
# ...

# %% [markdown]
# #### <span style="color: lightpink;">Adjusted Linear Regressions:</span>

# %%
#Create an adjusted linear regession model of the EPDS score with the Language as the independent variable and the Anxiety Score, Gestational Age, Birth Weight as covariates
#Create the design matrix
y, X = dmatrices('Edinburgh_Postnatal_Depression_Scale ~ Language + PROMIS_Anxiety + Gestational_Age_At_Birth + Birth_Weight', data=df, return_type='dataframe')
#Fit the model
model = sm.OLS(y, X).fit()
#Print the summary
print(model.summary())
# Out:
#                                      OLS Regression Results
# ...
# Dep. Variable:     Edinburgh_Postnatal_Depression_Scale   R-squared:                       0.649
# Model:                                              OLS   Adj. R-squared:                  0.648
# Method:                                   Least Squares   F-statistic:                     2626.
# Date:                                  Tue, 29 Apr 2025   Prob (F-statistic):               0.00
# Time:                                          20:56:29   Log-Likelihood:                -14633.
# No. Observations:                                  5694   AIC:                         2.928e+04
# Df Residuals:                                      5689   BIC:                         2.931e+04
# Df Model:                                             4
# Covariance Type:                              nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
#Create an adjusted linear regession model of the Anxiety score with the Language as the independent variable and the EPDS Score, Gestational Age, Birth Weight as covariates
#Create the design matrix
y, X = dmatrices('PROMIS_Anxiety ~ Language + Edinburgh_Postnatal_Depression_Scale + Gestational_Age_At_Birth + Birth_Weight', data=df, return_type='dataframe')
#Fit the model
model = sm.OLS(y, X).fit()
#Print the summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         PROMIS_Anxiety   R-squared:                       0.648
# Model:                            OLS   Adj. R-squared:                  0.648
# Method:                 Least Squares   F-statistic:                     2618.
# Date:                Tue, 29 Apr 2025   Prob (F-statistic):               0.00
# Time:                        20:57:04   Log-Likelihood:                -15265.
# No. Observations:                5694   AIC:                         3.054e+04
# Df Residuals:                    5689   BIC:                         3.057e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# ...

# %%
#Create an adjusted linear regession model of the Gestational Age at Birth with the Language as the independent variable and the EPDS Score, Anxiety Score, Birth Weight as covariates
#Create the design matrix
y, X = dmatrices('Gestational_Age_At_Birth ~ Language + Edinburgh_Postnatal_Depression_Scale + PROMIS_Anxiety + Birth_Weight', data=df, return_type='dataframe')
#Fit the model
model = sm.OLS(y, X).fit()
#Print the summary
print(model.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     Gestational_Age_At_Birth   R-squared:                       0.315
# Model:                                  OLS   Adj. R-squared:                  0.315
# Method:                       Least Squares   F-statistic:                     654.4
# Date:                      Tue, 29 Apr 2025   Prob (F-statistic):               0.00
# Time:                              20:57:21   Log-Likelihood:                -9743.5
# No. Observations:                      5694   AIC:                         1.950e+04
# Df Residuals:                          5689   BIC:                         1.953e+04
# Df Model:                                 4
# Covariance Type:                  nonrobust
# ...
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# ...

# %%
#Create an adjusted linear regession model of the Birth Weight with the Language as the independent variable and the EPDS Score, Anxiety Score, Gestational Age at Birth as covariates
#Create the design matrix
y, X = dmatrices('Birth_Weight ~ Language + Edinburgh_Postnatal_Depression_Scale + PROMIS_Anxiety + Gestational_Age_At_Birth', data=df, return_type='dataframe')
#Fit the model
model = sm.OLS(y, X).fit()
#Print the summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Birth_Weight   R-squared:                       0.314
# Model:                            OLS   Adj. R-squared:                  0.313
# Method:                 Least Squares   F-statistic:                     650.5
# Date:                Tue, 29 Apr 2025   Prob (F-statistic):               0.00
# Time:                        20:57:47   Log-Likelihood:                -42808.
# No. Observations:                5694   AIC:                         8.563e+04
# Df Residuals:                    5689   BIC:                         8.566e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## <span style="color: violet;">Discussion:</span>

# %% [markdown]
# #### <span style="color: lightpink;">Statistical Analysis (Indepdent T Tests):</span>
# #### <span style="color: light pink;"> Language was significantly associated with postnatal depression and anxiety scores, with English and French speakers differing in EPDS scores (t = 7.16, p < 0.00000000000009) and PROMIS Anxiety scores (t = 8.25, p < 0.00000000000000017), though these results reflect statistically significant but potentially small practical effects. Additionally, language was also significantly associated with birth weight (t = 3.61, p = 0.00031), whereas there was no significant difference in gestational age at birth between language groups (t = 0.84, p = 0.398), reinforcing that language plays a limited role in predicting birth outcomes beyond certain mental health associations.</span>

# %% [markdown]
# #### <span style="color: lightpink;">Statistical Analysis (Unudjusted Linear Regression):</span>
#
# #### <span style="color: light pink;"> We are 95 percent confident that French-speaking participants scored 0.95 points lower on the Edinburgh Postnatal Depression Scale compared to non-French speakers (β = -0.953, p < 0.001, 95% CI: [-1.214, -0.692]). While this difference is statistically significant, the model explains only 0.5% of the variance in depression scores (R² = 0.005, F(1, 9596) = 51.21, p < 0.001), indicating that language has a very small effect on postnatal depression in this dataset.</span>
#
# #### <span style="color: light pink;"> We are 95 percent confident that French-speaking participants scored 1.21 points lower on the PROMIS Anxiety scale than non-French speakers (β = -1.214, p < 0.001, 95% CI: [-1.503, -0.926]). While this difference is statistically significant, the overall model explains just 0.7% of the variance in anxiety scores (R² = 0.007, F(1, 9564) = 68.13, p < 0.001), indicating that language is not a strong predictor of anxiety levels on its own.</span>
#
#
# #### <span style="color: light pink;">We are 95 percent confident that there was no statistically significant difference in gestational age at birth between French-speaking and non-French-speaking participants (β = -0.0416, p = 0.398, 95% CI: [-0.138, 0.055]). The model explained virtually none of the variance in gestational age (R² = 0.000, F(1, 6732) = 0.71, p = 0.398), indicating that language is not a meaningful predictor of gestational age at birth in this dataset.</span>
#
#
# #### <span style="color: light pink;">We are 95 percent confident that French-speaking participants had infants with an average birth weight 63.37 grams lower than those of non-French speakers (β = -63.37, p < 0.001, 95% CI: [-97.79, -28.94]). Although this difference is statistically significant, the effect size is minimal, with language accounting for only 0.2% of the variance in birth weight (R² = 0.002, F(1, 6076) = 13.02, p = 0.00031), indicating that language is not a strong predictor of birth weight in this dataset.</span>

# %% [markdown]
# #### <span style="color: lightpink;">Statistical Analysis (Adjusted Linear Regression):</span>
#
# #### <span style="color: light pink;"> In the adjusted model, anxiety was the strongest predictor of postnatal depression, with each one-point increase in PROMIS Anxiety score associated with a 0.72-point increase in EPDS score (β = 0.718, p < 0.001, 95% CI: [0.704, 0.732]). Language remained a statistically significant predictor, with French speakers showing 0.40-point lower EPDS scores compared to non-French speakers (β = -0.397, p < 0.001, 95% CI: [-0.609, -0.186]). Gestational age and birth weight were not significant predictors in this model. Overall, the model explains a substantial 64.9% of the variance in depression scores (R² = 0.649, F(4, 5689) = 2626, p < 0.001), indicating a strong fit. </span>
#
# #### <span style="color: light pink;"> In the adjusted model, postnatal depression (EPDS) was the strongest predictor of anxiety, with each one-point increase in EPDS score linked to a 0.90-point increase in PROMIS Anxiety (β = 0.8966, p < 0.001, 95% CI: [0.879, 0.914]). Gestational age was also a modest but significant predictor, where higher gestational age was associated with slightly lower anxiety scores (β = -0.0759, p = 0.030, 95% CI: [-0.144, -0.007]). Language and birth weight were not significant predictors in this model. Overall, the model explained a substantial 64.8% of the variance in anxiety scores (R² = 0.648, F(4, 5689) = 2618, p < 0.001), indicating a strong overall fit.</span>
#
#
# #### <span style="color: light pink;"> In this adjusted model, birth weight was the strongest predictor of gestational age at birth, with each gram increase in birth weight associated with a 0.0017-week increase in gestational age (β = 0.0017, p < 0.001, 95% CI: [0.002, 0.002]). Anxiety also showed a small but statistically significant negative association, where higher anxiety scores were linked to slightly shorter gestational ages (β = -0.0109, p = 0.030, 95% CI: [-0.021, -0.001]). However, language (β = 0.0468, p = 0.306) and depression scores (β = -0.0048, p = 0.392) were not significant predictors. The model explains 31.5% of the variance in gestational age (R² = 0.315, F(4, 5689) = 654.4, p < 0.001), indicating a moderately strong overall fit.</span>
#
#
# #### <span style="color: light pink;"> In this adjusted model, gestational age at birth was the strongest predictor of birth weight, with each additional week of gestation associated with a 185.57-gram increase in birth weight (β = 185.57, p < 0.001, 95% CI: [178.40, 192.75]). Language also had a significant effect, as French-speaking participants had babies weighing 55.28 grams less on average than non-French speakers (β = -55.28, p < 0.001, 95% CI: [-85.09, -25.47]). However, depression (β = -2.12, p = 0.256) and anxiety scores (β = 2.28, p = 0.173) were not significant predictors. Overall, the model explains 31.4% of the variance in birth weight (R² = 0.314, F(4, 5689) = 650.5, p < 0.001), indicating a moderately strong fit.</span>

# %% [markdown]
# ## <span style="color: violet;">Conclusion:</span>

# %% [markdown]
# #### <span style="color: lightpink;">Although language was significantly associated with EPDS, anxiety scores, and birth weight in both T Tests and regression models, its predictive power was minimal, with very low R² values in unadjusted analyses. In adjusted models, psychological factors like anxiety and depression were far stronger predictors of maternal and infant outcomes, suggesting that language alone is not a meaningful driver of these health indicators when controlling for other variables.</span>
