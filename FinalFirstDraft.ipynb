# %% [markdown]
# # <span style="color: violet;">Maternal Mental Health in Pregnancy during COVID-19
# Sophia Dalal
#
# April, 14, 2025 </span>

# %% [markdown]
# ## <span style="color: lightpink;">Prenatal mental health data and birth outcomes in the pregnancy during the COVID</span> </span>

# %% [markdown]
# ##### <span style="color: lightblue;">This Dataset aimed to understand the impact of COVID-19-related stresses on pregnant individuals and their infants and collected survey-based data across Canada as part of the Pregnancy during the COVID-19 Pandemic (PdP) project.</span> </span>.

# %% [markdown]
# ### <span style="color: violet;">Introduction </span>

# %% [markdown]
# #### <span style="color: violet;"> Here is a little description of all the variables used in the data set:
#  </span>

# %% [markdown]
# <span style="color: lightpink;"> 1. Maternal_Age: Maternal age (years) at intake <span>
#
#
# <span style="color: lightpink;">2. Household_Income: What is the total household income, before taxes and deductions, of all the household members from all sources in 2019<span>
#
#
# <span style="color: lightpink;">3. Maternal_Education: Maternal education<span>
#
#
# <span style="color: lightpink;">
#
# 1- Less than high school
#
# 2- diploma
#
# 3- High school diploma
#
# 4- College/trade school
#
# 5- Undergraduate degree
#
# 6- Master's degree
#
# 7- Doctoral Degree<span>
#
# <span style="color: lightpink;"> 4. EPDS: Edinburgh Postnatal Depression Scale (you can find the survey on the internet)<span>
#
# <span style="color: lightpink;"> 5. PROMIS_Anxiety: Score from 7 to 35 with higher scores indicating greater severity of anxiety. <span>
#
# <span style="color: lightpink;"> 6. GAbirth: Gestational age at birth (in weeks) <span>
#
# <span style="color: lightpink;"> 7. Delivery_Date: Delivery Date (Dates converted to month/year of birth)<span>
#
# <span style="color: lightpink;"> 8. Birth_Length: Birth length in cm<span>
#
# <span style="color: lightpink;"> 9. Birth_Weight: Birth weight in grams<span>
#
# <span style="color: lightpink;"> 10. Delivery_Mode: Vaginally or Caesarean-section (c-section)<span>
#
# <span style="color: lightpink;"> 11. NICU_stay: Was your infant admitted to the NICU?<span>
#
# <span style="color: lightpink;"> 12. Language: Survey language<span>
#
# <span style="color: lightpink;"> 13. Threaten_Life: How much do (did) you think your life is (was) in danger during the COVID-19 pandemic? (0-100)<span>
#
# <span style="color: lightpink;"> 14. Threaten_Baby_Danger: How much do (did) you think your unborn baby's life is (was) in danger at any time during the COVID-19 pandemic? (0-100)<span>
#
# <span style="color: lightpink;"> 15. Threaten_Baby_Harm: How much are you worried that exposure to the COVID-19 virus will harm your unborn baby? (0-100) <span>

# %% [markdown]
# ##### <span style="color: teal;">The COVID-19 pandemic posed significant challenges to maternal health worldwide, amplifying stress, anxiety, and depression among pregnant and postpartum individuals. These mental health challenges were not experienced equally—language barriers often exacerbated health disparities. Non-English speaking individuals may have faced reduced access to information, limited communication with healthcare providers, and increased social isolation, all of which can intensify psychological distress.<span>
#
# ##### <span style="color: teal;">Language can serve as a proxy for broader cultural and structural inequalities, influencing not only maternal mental health but also birth outcomes such as gestational age, birth weight, and NICU admission rates. Despite its importance, language-based disparities in perinatal health have been underexplored, particularly in the context of large-scale public health crises like COVID-19. <span>
#
# ##### <span style="color: teal;">By examining differences in mental health scores and birth outcomes between English and non-English speaking participants, this study aims to shed light on the intersection between linguistic marginalization and maternal-infant wellbeing, with implications for equitable care and policy design.<span>

# %% [markdown]
# ### <span style="color: violet;"> Are there differences in outcomes or mental health scores between English and non-English speaking participants?
#  </span>

# %% [markdown]
# ##### <span style="color: lightblue;"> Research Question: Are there differences in outcomes or mental health scores between English and non-English speaking participants? <span>
#
# ##### <span style="color: lightpink;"> Goal: Is Lanaguage a predictor for any mental health outcomes or baby outcomes?
#
# ##### <span style="color: lightpink;"> Independent Variable= Language <span>
#
# ##### <span style="color: lightpink;"> Dependent Variables = EPDS score, POMIS anxiety scales, Birth Weight, Gestational Age <span>
#
# ##### <span style="color: lightblue;"> Methods: Chi-square tests for categorical outcomes; t-tests or regression for continuous.<span>
#
# #### <span style="color: lightblue;"> Implication: Language as a proxy for health inequities.<span>

# %% [markdown]
# #### Import all packages

# %%
import numpy
from plotly import graph_objects, figure_factory
import pandas
from scipy import stats
import seaborn
import matplotlib as plt
import matplotlib.pyplot

# %% [markdown]
# #### Import Data Set

# %%
df = pandas.read_csv('Original Pregnancy During the COVID-19 Pandemic 2.csv')

# %% [markdown]
# #### Previewing the Data

# %% [markdown]
# ### <span style="color: violet;"> Are there differences in outcomes or mental health scores between English and non-English speaking participants?
#  </span>

# %%
#show the first 5 rows
df.head()
# Out:
#    OSF_ID  Maternal_Age    Household_Income    Maternal_Education  \
# 0       1          38.3           $200,000+        Masters degree
# 1       2          34.6           $200,000+  Undergraduate degree
# 2       3          34.3  $100,000 -$124,999  Undergraduate degree
# 3       4          28.8  $100,000 -$124,999        Masters degree
# 4       5          36.5     $40,000-$69,999  Undergraduate degree
#
#    Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0                                   9.0            13.0
# 1                                   4.0            17.0
# 2                                   NaN             NaN
# 3                                   9.0            20.0
# 4                                  14.0            20.0
#
#    Gestational_Age_At_Birth Delivery_Date(converted to month and year)  \
# 0                     39.71                                    Dec2020
# 1                       NaN                                        NaN
# ...

# %%
#show all the column names
df.columns
# Out:
# Index(['OSF_ID', 'Maternal_Age', 'Household_Income', 'Maternal_Education',
#        'Edinburgh_Postnatal_Depression_Scale', 'PROMIS_Anxiety',
#        'Gestational_Age_At_Birth',
#        'Delivery_Date(converted to month and year)', 'Birth_Length',
#        'Birth_Weight', 'Delivery_Mode', 'NICU_Stay', 'Language',
#        'Threaten_Life', 'Threaten_Baby_Danger', 'Threaten_Baby_Harm'],
#       dtype='object')

# %% [markdown]
# #### First Look at the data

# %%
# Calculate the frequency of each category in the language column
df['Language'].value_counts()
# Out:
# Language
# English    8155
# French     2617
# Name: count, dtype: int64

# %%
#show the unique values in the Language column
df['Language'].unique()
# Out:
# array(['English', 'French'], dtype=object)

# %%
# Calculate the frequency of each category in the Birth_Length, Gestational_Age_At_Birth, Birth_Weight coluumns on seperate lines 
df['Birth_Length'].value_counts()
# Out:
# Birth_Length
# 53.34    565
# 50.80    526
# 48.26    395
# 51.00    379
# 50.00    362
#         ...
# 51.20      1
# 44.50      1
# 45.47      1
# 60.33      1
# 50.52      1
# Name: count, Length: 172, dtype: int64

# %%
df['Gestational_Age_At_Birth'].value_counts()
# Out:
# Gestational_Age_At_Birth
# 39.14    322
# 40.00    300
# 39.43    289
# 39.86    281
# 39.29    278
#         ...
# 27.00      1
# 26.57      1
# 28.43      1
# 30.29      1
# 42.86      1
# Name: count, Length: 97, dtype: int64

# %%
df['Birth_Weight'].value_counts()
# Out:
# Birth_Weight
# 3402.0    164
# 3544.0    128
# 3431.0    125
# 3487.0    125
# 3345.0    125
#          ...
# 4360.0      1
# 2830.0      1
# 4115.0      1
# 3173.0      1
# 5048.0      1
# Name: count, Length: 706, dtype: int64

# %% [markdown]
# #### <span style="color: MediumPurple;">Numerical Data Analysis</span>

# %% [markdown]
# #### <span style="color: LightBlue;">Below are ways to play with numerical variable such as Birth Weight, Gestational age, and Birth Length</span>

# %%
# Describe the summary statistics of the "Birth_Weight", Gestational age, and Birth Length column
df['Birth_Weight'].describe()
# Out:
# count    6078.000000
# mean     3412.175058
# std       538.695046
# min       303.000000
# 25%      3102.250000
# 50%      3431.000000
# 75%      3742.000000
# max      5968.000000
# Name: Birth_Weight, dtype: float64

# %%
df['Gestational_Age_At_Birth'].describe()
# Out:
# count    6734.000000
# mean       39.342241
# std         1.612483
# min        24.860000
# 25%        38.570000
# 50%        39.570000
# 75%        40.430000
# max        42.860000
# Name: Gestational_Age_At_Birth, dtype: float64

# %%
df['Birth_Length'].describe()
# Out:
# count    5480.000000
# mean       50.502504
# std         4.445347
# min        20.000000
# 25%        49.000000
# 50%        50.800000
# 75%        53.030000
# max        70.000000
# Name: Birth_Length, dtype: float64

# %%
# Describe the summary statistics of the "Edinburgh_Postnatal_Depression_Scale", "PROMIS_Anxiety", and "Threaten_Life"column
df['Edinburgh_Postnatal_Depression_Scale'].describe()
# Out:
# count    9598.000000
# mean       10.194832
# std         5.505230
# min         0.000000
# 25%         6.000000
# 50%        10.000000
# 75%        14.000000
# max        30.000000
# Name: Edinburgh_Postnatal_Depression_Scale, dtype: float64

# %%
df['PROMIS_Anxiety'].describe()
# Out:
# count    9566.000000
# mean       18.677713
# std         6.084313
# min         7.000000
# 25%        14.000000
# 50%        19.000000
# 75%        23.000000
# max        35.000000
# Name: PROMIS_Anxiety, dtype: float64

# %%
# Describe the summary stats for the Birth_Length column for each category in the Language column 
df.groupby('Language')['Birth_Length'].describe()
# Out:
#            count       mean       std   min    25%   50%    75%   max
# Language
# English   4444.0  50.571049  4.542408  20.0  49.00  51.0  53.34  70.0
# French    1036.0  50.208475  3.991073  21.5  48.44  50.8  52.50  62.0

# %%
# Describe the summary stats for the Birth_Weight column for each category in the Language column
df.groupby('Language')['Birth_Weight'].describe()
# Out:
#            count         mean         std    min     25%     50%     75%  \
# Language
# English   4917.0  3424.279439  535.336730  303.0  3119.0  3431.0  3742.0
# French    1161.0  3360.911283  549.979257  314.0  3080.0  3374.0  3689.0
#
#              max
# Language
# English   5968.0
# French    5675.0

# %%
# Describe the summary stats for the Gestational_Age_At_Birth column for each category in the Language column
df.groupby('Language')['Gestational_Age_At_Birth'].describe()
# Out:
#            count      mean       std    min    25%    50%    75%    max
# Language
# English   5398.0  39.35050  1.613136  24.86  38.57  39.43  40.43  42.86
# French    1336.0  39.30887  1.610013  27.29  38.57  39.57  40.29  42.29

# %%
# Describe the summary stats for the Edinburgh_Postnatal_Depression_Scale column for each category in the Language column
df.groupby('Language')['Edinburgh_Postnatal_Depression_Scale'].describe()
# Out:
#            count       mean       std  min  25%   50%   75%   max
# Language
# English   7388.0  10.414185  5.399369  0.0  6.0  10.0  14.0  30.0
# French    2210.0   9.461538  5.786422  0.0  5.0   9.0  13.0  29.0

# %%
# Describe the summary stats for the PROMIS_Anxiety column for each category in the Language column
df.groupby('Language')['PROMIS_Anxiety'].describe()
# Out:
#            count       mean       std  min   25%   50%   75%   max
# Language
# English   7358.0  18.958005  6.032827  7.0  14.0  19.0  23.0  35.0
# French    2208.0  17.743659  6.162830  7.0  13.0  18.0  23.0  35.0

# %% [markdown]
# #### <span style="color: MediumPurple;">Data Visualization</span>

# %% [markdown]
# #### <span style="color: LightBlue;">Below are ways to visually see Language as a predictor for these models</span>

# %%
# Show the best plot of the Birth_Length column and the Language column
seaborn.boxplot(x='Language', y='Birth_Length', data=df)
plt.pyplot.title('Birth Length by Language')
plt.pyplot.xlabel('Language')
plt.pyplot.ylabel('Birth Length')
plt.pyplot.show()

# %%
# Show the best plot of the Birth_Weight column and the Language column
seaborn.boxplot(x='Language', y='Birth_Weight', data=df)
plt.pyplot.title('Birth Weight by Language')
plt.pyplot.xlabel('Language')
plt.pyplot.ylabel('Birth Weight')
plt.pyplot.show()

# %%
# Show the best plot of the Gestational Age at birth column and the Language column
seaborn.boxplot(x='Language', y='Gestational_Age_At_Birth', data=df)
plt.pyplot.title('Gestational Age at Birth by Language')
plt.pyplot.xlabel('Language')
plt.pyplot.ylabel('Gestational Age at Birth')
plt.pyplot.show()

# %%
# Show the best plot of the Edinburgh Postnatal Depression Scale column and the Language column
seaborn.boxplot(x='Language', y='Edinburgh_Postnatal_Depression_Scale', data=df)
plt.pyplot.title('Edinburgh Postnatal Depression Scale by Language')
plt.pyplot.xlabel('Language')
plt.pyplot.ylabel('Edinburgh Postnatal Depression Scale')
plt.pyplot.show()

# %%
# Show the best plot of the PROMIS Anxiety column and the Language column
seaborn.boxplot(x='Language', y='PROMIS_Anxiety', data=df)
plt.pyplot.title('PROMIS Anxiety by Language')
plt.pyplot.xlabel('Language')
plt.pyplot.ylabel('PROMIS Anxiety')
plt.pyplot.show()

# %%
# Show two side by sizse dot plots of all the values Birth Length and English Speakers and then the same with french speakers
seaborn.stripplot(x='Language', y='Birth_Length', data=df, jitter=True)
plt.pyplot.title('Birth Length by Language')
plt.pyplot.xlabel('Language')
plt.pyplot.ylabel('Birth Length')
plt.pyplot.show()
seaborn.stripplot(x='Language', y='Birth_Weight', data=df, jitter=True)
plt.pyplot.title('Birth Weight by Language')
plt.pyplot.xlabel('Language')
plt.pyplot.ylabel('Birth Weight')
plt.pyplot.show()
seaborn.stripplot(x='Language', y='Gestational_Age_At_Birth', data=df, jitter=True)
plt.pyplot.title('Gestational Age at Birth by Language')
plt.pyplot.xlabel('Language')
plt.pyplot.ylabel('Gestational Age at Birth')
plt.pyplot.show()
seaborn.stripplot(x='Language', y='Edinburgh_Postnatal_Depression_Scale', data=df, jitter=True)
plt.pyplot.title('Edinburgh Postnatal Depression Scale by Language')
plt.pyplot.xlabel('Language')
plt.pyplot.ylabel('Edinburgh Postnatal Depression Scale')
plt.pyplot.show()
seaborn.stripplot(x='Language', y='PROMIS_Anxiety', data=df, jitter=True)
plt.pyplot.title('PROMIS Anxiety by Language')
plt.pyplot.xlabel('Language')
plt.pyplot.ylabel('PROMIS Anxiety')
plt.pyplot.show()

# %%
# Show a Frequencey Distribution Plot of the Birth Length column
seaborn.histplot(df['Birth_Length'], kde=True)
plt.pyplot.title('Frequency Distribution of Birth Length')
plt.pyplot.xlabel('Birth Length')
plt.pyplot.ylabel('Frequency')
plt.pyplot.show()
#Show the Language Variable as a hue
seaborn.histplot(df, x='Birth_Length', hue='Language', kde=True)
plt.pyplot.title('Frequency Distribution of Birth Length by Language')
plt.pyplot.xlabel('Birth Length')
plt.pyplot.ylabel('Frequency')
plt.pyplot.show()

# %%
# Show a Frequencey Distribution Plot of the EPDS column
seaborn.histplot(df['Edinburgh_Postnatal_Depression_Scale'], kde=True)
plt.pyplot.title('Frequency Distribution of Edinburgh Postnatal Depression Scale')
plt.pyplot.xlabel('Edinburgh Postnatal Depression Scale')
plt.pyplot.ylabel('Frequency')
plt.pyplot.show()
#Show the Language Variable as a hue
seaborn.histplot(df, x='Edinburgh_Postnatal_Depression_Scale', hue='Language', kde=True)
plt.pyplot.title('Frequency Distribution of Edinburgh Postnatal Depression Scale by Language')
plt.pyplot.xlabel('Edinburgh Postnatal Depression Scale')
plt.pyplot.ylabel('Frequency')
plt.pyplot.show()
